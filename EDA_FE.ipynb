# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('ENB2012_data.xlsx',engine='openpyxl')

# %%
df.head()
# Out:
#      X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2  Unnamed: 10  \
# 0  0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33          NaN
# 1  0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33          NaN
# 2  0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33          NaN
# 3  0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33          NaN
# 4  0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28          NaN
#
#    Unnamed: 11
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.drop(["Unnamed: 10","Unnamed: 11"],axis=1,inplace=True)

# %%
column={"X1":"Relative Compactness",
"X2":"Surface Area",
"X3":"Wall Area",
"X4":"Roof Area",
"X5":"Overall Height",
"X6":"Orientation",
"X7":"Glazing Area",
"X8":"Glazing Area Distribution",
"y1":"Heating Load",
"y2":"Cooling Load"}

# %%
df.dropna(inplace=True)

# %%
df.to_csv("cleaned_data.csv",index=False)

# %%
df=pd.read_csv("cleaned_data.csv")

# %%
df.isnull().value_counts()
# Out:
# X1     X2     X3     X4     X5     X6     X7     X8     Y1     Y2
# False  False  False  False  False  False  False  False  False  False    768
# dtype: int64

# %% [markdown]
# ### No missing values found in dataset

# %%
df.dtypes
# Out:
# X1    float64
# X2    float64
# X3    float64
# X4    float64
# X5    float64
# X6    float64
# X7    float64
# X8    float64
# Y1    float64
# Y2    float64
# dtype: object

# %%
df.head()
# Out:
#      X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28

# %%
[print(f"unique value in {i} is {df[i].nunique()}") for i in df.columns.tolist()]
# Out:
# unique value in X1 is 12
# unique value in X2 is 12
# unique value in X3 is 7
# unique value in X4 is 4
# unique value in X5 is 2
# unique value in X6 is 4
# unique value in X7 is 4
# unique value in X8 is 6
# unique value in Y1 is 587
# unique value in Y2 is 636
# [None, None, None, None, None, None, None, None, None, None]

# %%
sns.pairplot(df)

# %%
for i in df.columns:
    if i!='Y1' or i!='Y2':
        sns.distplot(df[i])
        plt.show()
        print("Skewness: %f" %df[i].skew())
        print("Kurtosis: %f" %df[i].kurt())
# Out:
# c:\users\1672040\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\1672040\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Skewness: 0.495513
# Kurtosis: -0.706568
# Skewness: -0.125131
# Kurtosis: -1.059454
# ...

# %%
sns.pairplot(df)

# %%
fig, ax = plt.subplots(figsize=(15,15))

sns.heatmap(df.corr(),annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# * From above plot it's evidentent that mutile features are higly colinear with each other but since number of feature is less that's why we will not any features
#
# * Since they possively correlated we will first predict y1 and then y1 will be used as input to predict y2
